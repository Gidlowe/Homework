# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing Chipotle Data
#
# _Author: Joseph Nelson (DC)_
#
# ---

# %% [markdown]
# https://github.com/TheUpshot/chipotle
#
# For project two, you will complete a series of exercises exploring [order data from Chipotle](https://github.com/TheUpshot/chipotle), compliments of The New York Times's "The Upshot."
#
# For these exercises, you are conducting basic exploratory data analysis (Pandas not required) to understand the basics of Chipotle's order data: how many orders are being made, what is the average price per order, how many different ingredients, etc. These allow you to conduct business analyst skills while becoming comfortable with Python.

# %% [markdown]
# ---
#
# ## Basic Level

# %% [markdown]
# ### Part 1: Read in the file with `csv.reader()` and store it in an object called `file_nested_list`.
#
# Hint: This is a TSV (tab-separated value) file, and `csv.reader()` needs to be told how to handle it.
#       https://docs.python.org/2/library/csv.html

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/TheUpshot/chipotle/master/orders.tsv'
    
file_nested_list = pd.read_csv(url, sep = '\t')

# %%
file_nested_list.columns
# Out:
# Index([u'order_id', u'quantity', u'item_name', u'choice_description',
#        u'item_price'],
#       dtype='object')

# %%
file_nested_list = pd.DataFrame(file_nested_list, columns = file_nested_list.keys())
file_nested_list
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
file_nested_list.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Part 2: Separate `file_nested_list` into the `header` and the `data`.

# %%
file_nested_list.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ---
#
# ## Intermediate Level

# %% [markdown]
# ### Part 3: Calculate the average price of an order.
#
# Hint: Examine the data to see if the `quantity` column is relevant to this calculation.
#
# Hint: Think carefully about the simplest way to do this!

# %%
file_nested_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %%
dollarizer = lambda x: float(x[1:-1])
file_nested_list.item_price = file_nested_list.item_price.apply(dollarizer)

# %%
a=file_nested_list.item_price.sum()

# %%
b=file_nested_list.quantity.sum()

# %%
print 34500.16000000046/(4972)
# Out:
# 6.93888978278

# %%
#price per order
print (file_nested_list.item_price.sum())/(file_nested_list.order_id.value_counts().count())
# Out:
# 18.8114285714

# %%
#price per item
print (file_nested_list.item_price.sum())/(file_nested_list.quantity.sum())
# Out:
# 6.93888978278

# %% [markdown]
# ### Part 4: Create a list (or set) named `unique_sodas` containing all unique sodas and soft drinks that they sell.
#
# Note: Just look for 'Canned Soda' and 'Canned Soft Drink', and ignore other drinks like 'Izze'.

# %%
file_nested_list.item_name.value_counts().head(100)
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
Unique_sodas=[]

Unique_sodas.append(file_nested_list[file_nested_list['item_name'] =='Canned Soft Drink'])
#file_nested_list[file_nested_list['item_name'] == 'Canned Soda']

# %%
Unique_sodas.append(file_nested_list[file_nested_list['item_name'] == 'Canned Soda'])

# %%
Unique_sodas
# Out:
# [      order_id  quantity          item_name choice_description  item_price
#  263        114         1  Canned Soft Drink             [Coke]        1.25
#  292        127         1  Canned Soft Drink           [Sprite]        1.25
#  320        139         1  Canned Soft Drink             [Coke]        1.25
#  337        147         1  Canned Soft Drink             [Coke]        1.25
#  346        149         1  Canned Soft Drink         [Lemonade]        1.25
#  347        149         1  Canned Soft Drink           [Sprite]        1.25
#  368        159         1  Canned Soft Drink        [Diet Coke]        1.25
#  380        165         1  Canned Soft Drink             [Coke]        1.25
#  381        165         1  Canned Soft Drink             [Coke]        1.25
#  393        170         1  Canned Soft Drink             [Coke]        1.25
#  401        174         1  Canned Soft Drink           [Sprite]        1.25
# ...

# %% [markdown]
# ---
#
# ## Advanced Level

# %% [markdown]
# ### Part 5: Calculate the average number of toppings per burrito.
#
# Note: Let's ignore the `quantity` column to simplify this task.
#
# Hint: Think carefully about the easiest way to count the number of toppings!

# %%
#file_nested_list.columns ['item_name', 'choice_description']
file_nested_list
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %% [markdown]
# ### Part 6: Create a dictionary. Let the keys represent chip orders and the values represent the total number of orders.
#
# Expected output: `{'Chips and Roasted Chili-Corn Salsa': 18, ... }`
#
# Note: Please take the `quantity` column into account!
#
# Optional: Learn how to use `defaultdict` to simplify your code.

# %% [markdown]
# ---
#
# ## Bonus: Craft a problem statement about this data that interests you, and then answer it!
